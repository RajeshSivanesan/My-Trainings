# %%
## Import libraries which is needed!
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, auc, roc_auc_score

# %%
# !conda install -c conda-forge scikit-plot -y
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import scikitplot as skplt

# %%
train = pd.read_csv("Employee-Attrition-Rate/Dataset/Train.csv")

# %%
train.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# ...

# %%
test = pd.read_csv("Employee-Attrition-Rate/Dataset/Test.csv")

# %%
test.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_22713      F  32.0                5              Single  Springfield
# 1    EID_9658      M  65.0                2              Single      Lebanon
# 2   EID_22203      M  52.0                3             Married  Springfield
# 3    EID_7652      M  50.0                5              Single   Washington
# 4    EID_6516      F  44.0                3             Married     Franklin
#
#         Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0        R&D             Conceptual              7.0                     4
# 1         IT              Directive             41.0                     2
# 2      Sales              Directive             21.0                     3
# 3  Marketing             Analytical             11.0                     4
# 4        R&D             Conceptual             12.0                     4
#
# ...

# %%
submission = pd.read_csv("Employee-Attrition-Rate/Dataset/sample_submission.csv")

# %%
submission
# Out:
#   Employee_ID  Attrition_rate
# 0       TID_1          0.1588
# 1       TID_2          0.1424
# 2       TID_3          0.4758
# 3       TID_4          0.0846
# 4       TID_5          0.2388

# %%
train.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Education_Level',
#        'Relationship_Status', 'Hometown', 'Unit', 'Decision_skill_possess',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Compensation_and_Benefits',
#        'Work_Life_balance', 'VAR1', 'VAR2', 'VAR3', 'VAR4', 'VAR5', 'VAR6',
#        'VAR7', 'Attrition_rate'],
#       dtype='object')

# %%
train.shape, test.shape
# Out:
# ((7000, 24), (3000, 23))

# %%
train.isna().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          412
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service              144
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      9
# Compensation_and_Benefits      0
# Work_Life_balance             11
# VAR1                           0
# VAR2                         577
# VAR3                           0
# VAR4                         656
# VAR5                           0
# VAR6                           0
# VAR7                           0
# Attrition_rate                 0
# dtype: int64

# %%
data = pd.concat([train,test])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                10000 non-null  object
#  1   Gender                     10000 non-null  object
#  2   Age                        9427 non-null   float64
#  3   Education_Level            10000 non-null  int64
#  4   Relationship_Status        10000 non-null  object
#  5   Hometown                   10000 non-null  object
#  6   Unit                       10000 non-null  object
#  7   Decision_skill_possess     10000 non-null  object
#  8   Time_of_service            9804 non-null   float64
#  9   Time_since_promotion       10000 non-null  int64
#  10  growth_rate                10000 non-null  int64
#  11  Travel_Rate                10000 non-null  int64
#  12  Post_Level                 10000 non-null  int64
# ...

# %%
data.describe().T
# Out:
#                         count       mean        std      min      25%  \
# Age                    9427.0  39.675507  13.574856  19.0000  27.0000
# Education_Level       10000.0   3.199400   1.065436   1.0000   3.0000
# Time_of_service        9804.0  13.390657  10.311381   0.0000   5.0000
# Time_since_promotion  10000.0   2.378600   1.149780   0.0000   1.0000
# growth_rate           10000.0  47.008400  15.848553  20.0000  33.0000
# Travel_Rate           10000.0   0.820700   0.646524   0.0000   0.0000
# Post_Level            10000.0   2.797000   1.171037   1.0000   2.0000
# Pay_Scale              9988.0   6.022627   2.070087   1.0000   5.0000
# Work_Life_balance      9984.0   2.385817   1.128782   1.0000   1.0000
# VAR1                  10000.0   3.089100   0.831884   1.0000   3.0000
# VAR2                   9206.0   0.002653   0.992949  -1.8176  -0.9612
# VAR3                  10000.0  -0.005826   0.990812  -2.7762  -0.4537
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_23371      F  42.0                4             Married
# 1      EID_18000      M  24.0                3              Single
# 2       EID_3891      F  58.0                3             Married
# 3      EID_17492      F  26.0                3              Single
# 4      EID_22534      F  31.0                1             Married
# ...          ...    ...   ...              ...                 ...
# 2995   EID_22547      F  32.0                3              Single
# 2996   EID_10066      F   NaN                2              Single
# 2997    EID_7126      F  60.0                4              Single
# 2998    EID_4929      F  51.0                1             Married
# 2999   EID_24750      F  45.0                1              Single
#
#          Hometown                       Unit Decision_skill_possess  \
# 0        Franklin                         IT             Conceptual
# ...

# %%
data = data.reset_index(drop=True)

# %%
data.corr()
# Out:
#                            Age  Education_Level  Time_of_service  \
# Age                   1.000000        -0.019583         0.917295
# Education_Level      -0.019583         1.000000        -0.023769
# Time_of_service       0.917295        -0.023769         1.000000
# Time_since_promotion  0.160433        -0.004403         0.146848
# growth_rate          -0.000487         0.004248        -0.004935
# Travel_Rate           0.010592        -0.018508         0.009064
# Post_Level           -0.012755         0.003910        -0.014277
# Pay_Scale             0.008032         0.001540         0.011298
# Work_Life_balance     0.000100        -0.007092        -0.002006
# VAR1                  0.000669        -0.000978        -0.000426
# VAR2                  0.006181        -0.011788         0.006772
# VAR3                  0.005103        -0.012551         0.003769
# VAR4                 -0.001340        -0.006163        -0.004993
# ...

# %%
matplotlib.rcParams["figure.figsize"] = (20,30)
sns.heatmap(data.corr(), annot=True,)
# Out:
# <AxesSubplot:>

# %%
data.Attrition_rate.value_counts()
# Out:
# 0.1042    10
# 0.1294     9
# 0.0312     9
# 0.1506     8
# 0.0015     8
#           ..
# 0.4958     1
# 0.0699     1
# 0.3687     1
# 0.2768     1
# 0.2583     1
# Name: Attrition_rate, Length: 3317, dtype: int64

# %%
matplotlib.rcParams["figure.figsize"] = (10,10)

# %%
data["Age"].value_counts()
# Out:
# 22.0    347
# 27.0    336
# 25.0    320
# 26.0    305
# 54.0    304
# 37.0    302
# 60.0    300
# 52.0    299
# 35.0    288
# 30.0    286
# 31.0    283
# 42.0    277
# 28.0    277
# 45.0    274
# 47.0    270
# 32.0    270
# 24.0    264
# 21.0    242
# 65.0    213
# 19.0    213
# 23.0    208
# 59.0    194
# 20.0    176
# 58.0    170
# 50.0    156
# 29.0    154
# 33.0    145
# 51.0    142
# 41.0    141
# 34.0    140
# 56.0    140
# 36.0    138
# 43.0    137
# 49.0    137
# 57.0    136
# 38.0    135
# 55.0    135
# 53.0    133
# 46.0    132
# 64.0    125
# 44.0    123
# 40.0    123
# 48.0    122
# 39.0    120
# 63.0    103
# 62.0    101
# 61.0     91
# Name: Age, dtype: int64

# %%
data["Age"].fillna(data['Age'].mean(), inplace=True)

# %%
data.isna().sum()
# Out:
# Employee_ID                     0
# Gender                          0
# Age                             0
# Education_Level                 0
# Relationship_Status             0
# Hometown                        0
# Unit                            0
# Decision_skill_possess          0
# Time_of_service               196
# Time_since_promotion            0
# growth_rate                     0
# Travel_Rate                     0
# Post_Level                      0
# Pay_Scale                      12
# Compensation_and_Benefits       0
# Work_Life_balance              16
# VAR1                            0
# VAR2                          794
# VAR3                            0
# VAR4                          954
# VAR5                            0
# VAR6                            0
# VAR7                            0
# Attrition_rate               3000
# dtype: int64

# %%
data["Time_of_service"].fillna(data['Time_of_service'].mode()[0], inplace=True)

# %%
data.isna().sum()
# Out:
# Employee_ID                     0
# Gender                          0
# Age                             0
# Education_Level                 0
# Relationship_Status             0
# Hometown                        0
# Unit                            0
# Decision_skill_possess          0
# Time_of_service                 0
# Time_since_promotion            0
# growth_rate                     0
# Travel_Rate                     0
# Post_Level                      0
# Pay_Scale                      12
# Compensation_and_Benefits       0
# Work_Life_balance              16
# VAR1                            0
# VAR2                          794
# VAR3                            0
# VAR4                          954
# VAR5                            0
# VAR6                            0
# VAR7                            0
# Attrition_rate               3000
# dtype: int64

# %%
data.groupby('Time_of_service').Pay_Scale

# %%
import scipy
data.pivot_table(values="Time_of_service", index = "Pay_Scale",aggfunc = scipy.stats.mode)
# Out:
#           Time_of_service
# Pay_Scale
# 1.0         ([6.0], [26])
# 2.0         ([6.0], [33])
# 3.0         ([6.0], [36])
# 4.0        ([6.0], [130])
# 5.0        ([6.0], [162])
# 6.0        ([6.0], [168])
# 7.0        ([6.0], [108])
# 8.0        ([6.0], [183])
# 9.0         ([6.0], [75])
# 10.0        ([6.0], [30])

# %%
data['Time_of_service'].value_counts()
# Out:
# 6.0     951
# 5.0     700
# 3.0     687
# 4.0     653
# 2.0     415
# 8.0     385
# 7.0     376
# 10.0    327
# 12.0    290
# 9.0     280
# 13.0    275
# 11.0    258
# 14.0    244
# 15.0    242
# 16.0    231
# 0.0     222
# 18.0    220
# 20.0    209
# 21.0    208
# 22.0    191
# 19.0    183
# 23.0    182
# 1.0     181
# 17.0    180
# 24.0    169
# 26.0    165
# 25.0    165
# 27.0    159
# 28.0    156
# 30.0    147
# 29.0    122
# 31.0    118
# 32.0    106
# 33.0    102
# 34.0     93
# 35.0     79
# 36.0     79
# 37.0     70
# 38.0     58
# 39.0     36
# 40.0     32
# 41.0     24
# 42.0     21
# 43.0      9
# Name: Time_of_service, dtype: int64

# %%
data.Pay_Scale.fillna(data.groupby(["Time_of_service"]).Pay_Scale.median()[0], inplace=True)

# %%
data.isna().sum()
# Out:
# Employee_ID                     0
# Gender                          0
# Age                             0
# Education_Level                 0
# Relationship_Status             0
# Hometown                        0
# Unit                            0
# Decision_skill_possess          0
# Time_of_service                 0
# Time_since_promotion            0
# growth_rate                     0
# Travel_Rate                     0
# Post_Level                      0
# Pay_Scale                       0
# Compensation_and_Benefits       0
# Work_Life_balance              16
# VAR1                            0
# VAR2                          794
# VAR3                            0
# VAR4                          954
# VAR5                            0
# VAR6                            0
# VAR7                            0
# Attrition_rate               3000
# dtype: int64

# %%
data.groupby(["Decision_skill_possess"]).Work_Life_balance.mean()
# Out:
# Decision_skill_possess
# Analytical    2.402161
# Behavioral    2.366693
# Conceptual    2.384864
# Directive     2.389783
# Name: Work_Life_balance, dtype: float64

# %%
data.groupby(["Time_since_promotion"]).Work_Life_balance.mean()[0]
# Out:
# 2.388392857142857

# %%
data.groupby(["growth_rate"]).Work_Life_balance.mean()
# Out:
# growth_rate
# 20    2.411429
# 21    2.464481
# 22    2.339080
# 23    2.480392
# 24    2.365591
# 25    2.439306
# 26    2.430380
# 27    2.402062
# 28    2.362069
# 29    2.439791
# 30    2.305263
# 31    2.322222
# 32    2.433673
# 33    2.430168
# 34    2.374359
# 35    2.304348
# 36    2.426136
# 37    2.433155
# 38    2.481928
# 39    2.376344
# 40    2.418605
# 41    2.344828
# 42    2.391534
# 43    2.440476
# 44    2.242775
# 45    2.430052
# 46    2.325444
# 47    2.474684
# 48    2.362162
# 49    2.418478
# 50    2.551351
# 51    2.339806
# 52    2.251337
# 53    2.374233
# 54    2.421320
# 55    2.458101
# 56    2.410000
# 57    2.434555
# 58    2.415301
# 59    2.371859
# 60    2.338624
# 61    2.230769
# 62    2.263473
# 63    2.512658
# 64    2.323671
# 65    2.447368
# 66    2.465686
# 67    2.289617
# 68    2.489899
# 69    2.406780
# 70    2.311224
# 71    2.337209
# 72    2.350282
# 73    2.229508
# 74    2.320513
# Name: Work_Life_balance, dtype: float64

# %%
data.groupby(["Age"]).Work_Life_balance.median()
# Out:
# Age
# 19.000000    2.0
# 20.000000    3.0
# 21.000000    2.0
# 22.000000    2.0
# 23.000000    2.0
# 24.000000    2.0
# 25.000000    2.0
# 26.000000    2.0
# 27.000000    3.0
# 28.000000    2.0
# 29.000000    2.0
# 30.000000    2.0
# 31.000000    2.0
# 32.000000    2.0
# 33.000000    2.0
# 34.000000    2.0
# 35.000000    3.0
# 36.000000    2.0
# 37.000000    2.0
# 38.000000    2.0
# 39.000000    3.0
# 39.675507    2.0
# 40.000000    2.0
# 41.000000    3.0
# 42.000000    2.0
# 43.000000    2.5
# 44.000000    2.0
# 45.000000    2.0
# 46.000000    2.0
# 47.000000    2.0
# 48.000000    2.0
# 49.000000    3.0
# 50.000000    2.0
# 51.000000    2.0
# 52.000000    2.0
# 53.000000    2.0
# 54.000000    2.0
# 55.000000    2.0
# 56.000000    2.0
# 57.000000    2.0
# 58.000000    2.5
# 59.000000    2.0
# 60.000000    2.0
# 61.000000    2.0
# 62.000000    2.0
# 63.000000    3.0
# 64.000000    3.0
# 65.000000    2.0
# Name: Work_Life_balance, dtype: float64

# %%
data.groupby(["Gender"]).Work_Life_balance.mean()
# Out:
# Gender
# F    2.391185
# M    2.378281
# Name: Work_Life_balance, dtype: float64

# %%
data.Gender.value_counts()
# Out:
# F    5842
# M    4158
# Name: Gender, dtype: int64

# %%
data["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data["Gender"].replace({'F':1, 'M': 0 }, inplace=True)

# %%
data.Work_Life_balance.fillna(data.groupby(["Time_since_promotion"]).Work_Life_balance.mean()[0], inplace=True)

# %%
data.isna().sum()
# Out:
# Employee_ID                     0
# Gender                          0
# Age                             0
# Education_Level                 0
# Relationship_Status             0
# Hometown                        0
# Unit                            0
# Decision_skill_possess          0
# Time_of_service                 0
# Time_since_promotion            0
# growth_rate                     0
# Travel_Rate                     0
# Post_Level                      0
# Pay_Scale                       0
# Compensation_and_Benefits       0
# Work_Life_balance               0
# VAR1                            0
# VAR2                          794
# VAR3                            0
# VAR4                          954
# VAR5                            0
# VAR6                            0
# VAR7                            0
# Attrition_rate               3000
# dtype: int64

# %%
data.VAR2.fillna(data.groupby(["Time_of_service"]).VAR2.median()[0], inplace=True)

# %%
data.VAR4.fillna(data.groupby(["Time_of_service"]).VAR4.median()[0], inplace=True)

# %%
data.isna().sum()
# Out:
# Employee_ID                     0
# Gender                          0
# Age                             0
# Education_Level                 0
# Relationship_Status             0
# Hometown                        0
# Unit                            0
# Decision_skill_possess          0
# Time_of_service                 0
# Time_since_promotion            0
# growth_rate                     0
# Travel_Rate                     0
# Post_Level                      0
# Pay_Scale                       0
# Compensation_and_Benefits       0
# Work_Life_balance               0
# VAR1                            0
# VAR2                            0
# VAR3                            0
# VAR4                            0
# VAR5                            0
# VAR6                            0
# VAR7                            0
# Attrition_rate               3000
# dtype: int64

# %%
data.Relationship_Status.value_counts()
# Out:
# Married    6461
# Single     3539
# Name: Relationship_Status, dtype: int64

# %%
data["Relationship_Status"].replace({'Married':1, 'Single': 0 }, inplace=True)

# %%
data.Decision_skill_possess.value_counts()
# Out:
# Behavioral    2535
# Analytical    2501
# Directive     2488
# Conceptual    2476
# Name: Decision_skill_possess, dtype: int64

# %%
num_col = data.select_dtypes(include=np.number).columns

# %%
num_col
# Out:
# Index(['Gender', 'Age', 'Education_Level', 'Relationship_Status',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Work_Life_balance', 'VAR1', 'VAR2', 'VAR3',
#        'VAR4', 'VAR5', 'VAR6', 'VAR7', 'Attrition_rate'],
#       dtype='object')

# %%
cat_col = data.select_dtypes(exclude=np.number).drop(columns=['Employee_ID']).columns

# %%
cat_col
# Out:
# Index(['Hometown', 'Unit', 'Decision_skill_possess',
#        'Compensation_and_Benefits'],
#       dtype='object')

# %%
cat_col_tranform = pd.get_dummies(data[cat_col])

# %%
cat_col_tranform
# Out:
#       Hometown_Clinton  Hometown_Franklin  Hometown_Lebanon  \
# 0                    0                  1                 0
# 1                    0                  0                 0
# 2                    1                  0                 0
# 3                    0                  0                 1
# 4                    0                  0                 0
# ...                ...                ...               ...
# 9995                 0                  1                 0
# 9996                 0                  1                 0
# 9997                 0                  0                 1
# 9998                 0                  0                 0
# 9999                 0                  1                 0
#
#       Hometown_Springfield  Hometown_Washington  Unit_Accounting and Finance  \
# 0                        0                    0                            0
# 1                        1                    0                            0
# ...

# %%
data_preprocessed_cat_num = pd.concat([cat_col_tranform, data[num_col]], axis = 1)

# %%
train_preprocessd = data_preprocessed_cat_num.dropna(subset=["Attrition_rate"])

# %%
test_preprocessd = data_preprocessed_cat_num[data_preprocessed_cat_num["Attrition_rate"].isna()]

# %%
test_preprocessd = test_preprocessd.reset_index(drop=True)

# %%
test_preprocessd
# Out:
#       Hometown_Clinton  Hometown_Franklin  Hometown_Lebanon  \
# 0                    0                  0                 0
# 1                    0                  0                 1
# 2                    0                  0                 0
# 3                    0                  0                 0
# 4                    0                  1                 0
# ...                ...                ...               ...
# 2995                 0                  1                 0
# 2996                 0                  1                 0
# 2997                 0                  0                 1
# 2998                 0                  0                 0
# 2999                 0                  1                 0
#
#       Hometown_Springfield  Hometown_Washington  Unit_Accounting and Finance  \
# 0                        1                    0                            0
# 1                        0                    0                            0
# ...

# %%
train_preprocessd
# Out:
#       Hometown_Clinton  Hometown_Franklin  Hometown_Lebanon  \
# 0                    0                  1                 0
# 1                    0                  0                 0
# 2                    1                  0                 0
# 3                    0                  0                 1
# 4                    0                  0                 0
# ...                ...                ...               ...
# 6995                 0                  1                 0
# 6996                 0                  0                 1
# 6997                 0                  0                 0
# 6998                 0                  0                 0
# 6999                 0                  1                 0
#
#       Hometown_Springfield  Hometown_Washington  Unit_Accounting and Finance  \
# 0                        0                    0                            0
# 1                        1                    0                            0
# ...

# %%
test_preprocessd = test_preprocessd.drop(columns="Attrition_rate")

# %%
test_preprocessd
# Out:
#       Hometown_Clinton  Hometown_Franklin  Hometown_Lebanon  \
# 0                    0                  0                 0
# 1                    0                  0                 1
# 2                    0                  0                 0
# 3                    0                  0                 0
# 4                    0                  1                 0
# ...                ...                ...               ...
# 2995                 0                  1                 0
# 2996                 0                  1                 0
# 2997                 0                  0                 1
# 2998                 0                  0                 0
# 2999                 0                  1                 0
#
#       Hometown_Springfield  Hometown_Washington  Unit_Accounting and Finance  \
# 0                        1                    0                            0
# 1                        0                    0                            0
# ...

# %%
X = train_preprocessd.drop(columns=["Attrition_rate"])

# %%
y = train["Attrition_rate"]

# %%
logistic_model = LogisticRegression()

# %%
transformed_y = np.where(y > 0.2, 1, 0)

# %%
y
# Out:
# 0       0.1841
# 1       0.0670
# 2       0.0851
# 3       0.0668
# 4       0.1827
#          ...
# 6995    0.7839
# 6996    0.1055
# 6997    0.7847
# 6998    0.4162
# 6999    0.0910
# Name: Attrition_rate, Length: 7000, dtype: float64

# %%
logistic_model.fit(X, transformed_y)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_model.coef_
# Out:
# array([[-0.08907914, -0.0193196 , -0.05135031,  0.06637613,  0.01683368,
#         -0.00563624, -0.04259322, -0.09544936,  0.00378132, -0.016997  ,
#          0.01716004,  0.01347892,  0.04928405, -0.01887234,  0.06167201,
#         -0.00226207, -0.04010537, -0.00114766, -0.11267943,  0.03109284,
#          0.006195  ,  0.05695917,  0.06050721, -0.06011987, -0.12356336,
#         -0.0103224 , -0.09102412, -0.00298753, -0.01449238, -0.08397391,
#          0.00077105,  0.01708361,  0.00129421, -0.02424065,  0.01300541,
#         -0.00185127,  0.01379212, -0.05282438, -0.04824099, -0.02411299,
#         -0.05585098, -0.02054698, -0.01543188, -0.03336633]])

# %%
accuracy_score(transformed_y, logistic_model.predict(X))
# Out:
# 0.7021428571428572

# %%
confusion_matrix(transformed_y, logistic_model.predict(X))
# Out:
# array([[4915,    0],
#        [2085,    0]], dtype=int64)

# %%
test_X = test_preprocessd

# %%
test_pred=logistic_model.predict(test_X)

# %%
test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
test_probab = logistic_model.predict_proba(test_X)[:,1]

# %%
test_probab
# Out:
# array([0.36179155, 0.3078309 , 0.28992727, ..., 0.28822541, 0.22267201,
#        0.31882934])

# %%
submission
# Out:
#   Employee_ID  Attrition_rate
# 0   EID_23371          0.1588
# 1   EID_18000          0.1424
# 2    EID_3891          0.4758
# 3   EID_17492          0.0846
# 4   EID_22534          0.2388

# %%
submission
# Out:
#   Employee_ID  Attrition_rate
# 0   EID_23371          0.1588
# 1   EID_18000          0.1424
# 2    EID_3891          0.4758
# 3   EID_17492          0.0846
# 4   EID_22534          0.2388

# %%
submission['Employee_ID'] = train['Employee_ID']

# %%
test
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0                5              Single
# 1       EID_9658      M  65.0                2              Single
# 2      EID_22203      M  52.0                3             Married
# 3       EID_7652      M  50.0                5              Single
# 4       EID_6516      F  44.0                3             Married
# ...          ...    ...   ...              ...                 ...
# 2995   EID_22547      F  32.0                3              Single
# 2996   EID_10066      F   NaN                2              Single
# 2997    EID_7126      F  60.0                4              Single
# 2998    EID_4929      F  51.0                1             Married
# 2999   EID_24750      F  45.0                1              Single
#
#          Hometown       Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield        R&D             Conceptual              7.0
# ...

# %%
submission
# Out:
#   Employee_ID  Attrition_rate
# 0   EID_23371          0.1588
# 1   EID_18000          0.1424
# 2    EID_3891          0.4758
# 3   EID_17492          0.0846
# 4   EID_22534          0.2388

# %%
submission['Employee_ID'] = test['Employee_ID']

# %%
submission.shape
# Out:
# (5, 2)

# %%
final_result = pd.DataFrame({ 'Employee_ID': test['Employee_ID'], 'Attrition_rate': test_probab })

# %%
final_result
# Out:
#      Employee_ID  Attrition_rate
# 0      EID_22713        0.361792
# 1       EID_9658        0.307831
# 2      EID_22203        0.289927
# 3       EID_7652        0.346001
# 4       EID_6516        0.287186
# ...          ...             ...
# 2995   EID_22547        0.333389
# 2996   EID_10066        0.283871
# 2997    EID_7126        0.288225
# 2998    EID_4929        0.222672
# 2999   EID_24750        0.318829
#
# [3000 rows x 2 columns]

# %%
final_result.to_csv("Employee_Attrition_Submission.csv",index = False)

# %%
linear_model_no_penalty = LogisticRegression(penalty = 'none')

# %%
linear_model_no_penalty.fit(X, transformed_y)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(penalty='none')

# %%
train_pred = linear_model_no_penalty.predict(X)

# %%
train_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
roc_auc_score(transformed_y, train_pred)
# Out:
# 0.5

# %%
test_pred = linear_model_no_penalty.predict(test_X)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Attrition_rate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-09c8c310d28a> in <module>
# ...

# %%
test_probab_no_penalty = linear_model_no_penalty.predict_proba(test_X)[:,1]

# %%
test_probab_no_penalty
# Out:
# array([0.36587655, 0.30387959, 0.28043398, ..., 0.28521684, 0.2161829 ,
#        0.31542811])

# %%
final_result_no_penalty = pd.DataFrame({ 'Employee_ID': test['Employee_ID'], 'Attrition_rate': test_probab_no_penalty })

# %%
final_result.to_csv("Employee_Attrition_Submission_no_penalty.csv",index = False)

# %%
KNeightBours = KNeighborsClassifier()

# %%
KNeightBours.fit(X, transformed_y)
# Out:
# KNeighborsClassifier()

# %%
train_pred_kneighbours = KNeightBours.predict(X)

# %%
train_pred_kneighbours
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(transformed_y, train_pred_kneighbours)
# Out:
# 0.746

# %%
confusion_matrix(transformed_y, train_pred_kneighbours)
# Out:
# array([[4531,  384],
#        [1394,  691]], dtype=int64)

# %%
roc_auc_score(transformed_y, train_pred_kneighbours)
# Out:
# 0.626643344530886

# %%
test_pred_kneighbours = KNeightBours.predict(test_X)

# %%
final_result_kneightbours = pd.DataFrame({ 'Employee_ID': test['Employee_ID'], 'Attrition_rate': test_pred_kneighbours })

# %%
final_result.to_csv("Employee_Attrition_Submission_kneighbours.csv",index = False)

# %%
linear_regression_model = LinearRegression()

# %%
y
# Out:
# 0       0.1841
# 1       0.0670
# 2       0.0851
# 3       0.0668
# 4       0.1827
#          ...
# 6995    0.7839
# 6996    0.1055
# 6997    0.7847
# 6998    0.4162
# 6999    0.0910
# Name: Attrition_rate, Length: 7000, dtype: float64

# %%
X
# Out:
#       Hometown_Clinton  Hometown_Franklin  Hometown_Lebanon  \
# 0                    0                  1                 0
# 1                    0                  0                 0
# 2                    1                  0                 0
# 3                    0                  0                 1
# 4                    0                  0                 0
# ...                ...                ...               ...
# 6995                 0                  1                 0
# 6996                 0                  0                 1
# 6997                 0                  0                 0
# 6998                 0                  0                 0
# 6999                 0                  1                 0
#
#       Hometown_Springfield  Hometown_Washington  Unit_Accounting and Finance  \
# 0                        0                    0                            0
# 1                        1                    0                            0
# ...

# %%
linear_regression_model.fit(X,y)
# Out:
# LinearRegression()

# %%
mean_squared_error(y, linear_regression_model.predict(X),squared=False)
# Out:
# 0.18503941786112857

# %%
y_pred = linear_regression_model.predict(test_X)

# %%
mean_squared_error(y_pred, test_X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-f1c797b6cb69> in <module>
# ----> 1 mean_squared_error(y_pred, test_X)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     253
#     254     """
# --> 255     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     256         y_true, y_pred, multioutput)
#     257     check_consistent_length(y_true, y_pred, sample_weight)
#
# ...

# %%
y_pred
# Out:
# array([0.21467376, 0.19464456, 0.19011317, ..., 0.16613697, 0.15087586,
#        0.19693395])

# %%
final_result_linear_regression = pd.DataFrame({ 'Employee_ID': test['Employee_ID'], 'Attrition_rate': y_pred })

# %%
final_result_linear_regression.to_csv("Employee_Attrition_Submission_linear_regression.csv",index = False)

# %%
model_ridge = Ridge(alpha=0.5)
model_ridge.fit(X,y)
# Out:
# Ridge(alpha=0.5)

# %%
mean_squared_error(y, model_ridge.predict(X),squared=False)
# Out:
# 0.18503941828711962

# %%
y_pred = model_ridge.predict(test_X)

# %%
final_result_ridge = pd.DataFrame({ 'Employee_ID': test['Employee_ID'], 'Attrition_rate': y_pred })

# %%
y_pred
# Out:
# array([0.21466425, 0.19464528, 0.19011032, ..., 0.16614529, 0.15088614,
#        0.19694535])

# %%
final_result_ridge.to_csv("Employee_Attrition_Submission_linear_regression_ridge.csv",index = False)

# %%
model_lasso = Lasso(10000)
model_lasso.fit(X,y)
# Out:
# Lasso(alpha=10000)

# %%
mean_squared_error(y, model_lasso.predict(X),squared=False)
# Out:
# 0.18574000922221678

# %%
y_pred = model_lasso.predict(test_X)

# %%
y_pred
# Out:
# array([0.18937613, 0.18937613, 0.18937613, ..., 0.18937613, 0.18937613,
#        0.18937613])

# %%
final_result_lasso = pd.DataFrame({ 'Employee_ID': test['Employee_ID'], 'Attrition_rate': y_pred })

# %%
final_result_ridge.to_csv("Employee_Attrition_Submission_linear_regression_lasso.csv",index = False)

# %%
model_elasticnet = ElasticNet(l1_ratio=0.5, alpha= 1000)
model_elasticnet.fit(X,y)
# Out:
# ElasticNet(alpha=1000)

# %%
mean_squared_error(y, model_elasticnet.predict(X),squared=False)
# Out:
# 0.18574000922221678

# %%
train_preprocessd
# Out:
#       Hometown_Clinton  Hometown_Franklin  Hometown_Lebanon  \
# 0                    0                  1                 0
# 1                    0                  0                 0
# 2                    1                  0                 0
# 3                    0                  0                 1
# 4                    0                  0                 0
# ...                ...                ...               ...
# 6995                 0                  1                 0
# 6996                 0                  0                 1
# 6997                 0                  0                 0
# 6998                 0                  0                 0
# 6999                 0                  1                 0
#
#       Hometown_Springfield  Hometown_Washington  Unit_Accounting and Finance  \
# 0                        0                    0                            0
# 1                        1                    0                            0
# ...

# %%
trans = MinMaxScaler()

# %%
data_scaled = pd.DataFrame(trans.fit_transform(X.drop(columns=["Attrition_rate", "Employee_ID"])),columns=X.drop(columns=["Attrition_rate", "Employee_ID"]).columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-185-5232ed47b488> in <module>
# ----> 1 data_scaled = pd.DataFrame(trans.fit_transform(X.drop(columns=["Attrition_rate", "Employee_ID"])),columns=X.drop(columns=["Attrition_rate", "Employee_ID"]).columns)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
# ...

# %%
X
# Out:
#       Hometown_Clinton  Hometown_Franklin  Hometown_Lebanon  \
# 0                    0                  1                 0
# 1                    0                  0                 0
# 2                    1                  0                 0
# 3                    0                  0                 1
# 4                    0                  0                 0
# ...                ...                ...               ...
# 6995                 0                  1                 0
# 6996                 0                  0                 1
# 6997                 0                  0                 0
# 6998                 0                  0                 0
# 6999                 0                  1                 0
#
#       Hometown_Springfield  Hometown_Washington  Unit_Accounting and Finance  \
# 0                        0                    0                            0
# 1                        1                    0                            0
# ...
