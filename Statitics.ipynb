# %%
import pandas as pd

# %%
dataFrame1 = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/spotify.csv', index_col='Date', parse_dates = True)

# %%
dataFrame1
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
import matplotlib as plot
import seaborn as sea
import matplotlib.pyplot as plt

# %%
sea.set(rc={'figure.figsize': (12, 12)})
sea.lineplot(data = dataFrame1)
plot.title('Popularity')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-5424bd42c8f1> in <module>
#       1 sea.set(rc={'figure.figsize': (12, 12)})
#       2 sea.lineplot(data = dataFrame1)
# ----> 3 plot.title('Popularity')
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
sea.set(rc={'figure.figsize': (12, 12)})
sea.barplot(data = dataFrame1)
# Out:
# <AxesSubplot:>

# %%
dataFrame1.isna().sum()
plt.figure(figsize=(20,10))
# Out:
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.title('Popularity')
sea.set(rc={'figure.figsize': (20, 20)})
sea.lineplot(data = dataFrame1['Despacito'])
sea.lineplot(data = dataFrame1['Shape of You'])
plt.xlabel('sample x')
# Out:
# Text(0.5, 0, 'sample x')

# %%
sea.set(rc={'figure.figsize': (20, 20)})
sea.histplot(data = dataFrame1)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sea.set(rc={'figure.figsize': (20, 20)})
sea.factorplot(data = dataFrame1)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
flight_data = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/flight_delays.csv')
plt.figure(figsize= (16,6))
plt.title("Average Arrival delay for Inceptez Airlines WN, by month")

#defenition for the bar 
sea.barplot(x = flight_data.index, y = flight_data['WN'])

#Adding labels 
plt.ylabel("Arrival delay in mins")
plt.xlabel("The months as integers")
# Out:
# Text(0.5, 0, 'The months as integers')

# %%
plt.figure(figsize= (16, 6))
plt.title("Average Arrival delay for Inceptez Airlines WN, by month")

#defenition for the bar 
sea.heatmap(data = flight_data, annot=True)

#Adding labels 
plt.ylabel("Arrival delay in mins")
plt.xlabel("The months as integers")
# Out:
# Text(0.5, 30.5, 'The months as integers')

# %%
plt.figure(figsize= (16, 6))
plt.title("Average Arrival delay for Inceptez Airlines WN, by month")

#defenition for the bar 
sea.heatmap(data = flight_data.corr(), annot=True, vmin= -1, vmax = 1)

#Adding labels 
plt.ylabel("Arrival delay in mins")
plt.xlabel("The months as integers")
# Out:
# Text(0.5, 30.5, 'The months as integers')

# %%
insurance = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/insurance.csv')

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize= (6, 6))
sea.scatterplot(x = insurance['age'], y = insurance['charges'], hue = insurance['smoker'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
plt.figure(figsize= (6, 6))
sea.scatterplot(x = insurance['bmi'], y = insurance['charges'], hue = insurance['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
plt.figure(figsize= (6, 6))
sea.regplot(x = insurance['bmi'], y = insurance['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
plt.figure(figsize= (6, 6))
sea.lmplot(x = 'bmi', y = 'charges', hue = 'smoker', data = insurance)

# %%
plt.figure(figsize= (6, 6))
sea.swarmplot(x = insurance['smoker'], y = insurance['charges'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
plt.figure(figsize= (6, 6))
sea.stripplot(x = insurance['smoker'], y = insurance['charges'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
sea.pairplot(insurance)

# %%
#Distribution plots

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptez_batch_16/main/iris.csv', index_col='Id')

# %%
iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
plt.figure(figsize= (6, 6))
sea.distplot(a = iris['Petal Length (cm)'], kde = False)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Petal Length (cm)'>

# %%
plt.figure(figsize= (6, 6))
sea.kdeplot(x = iris['Petal Length (cm)'], shade =True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %%
plt.figure(figsize= (6, 6))
sea.jointplot(x = iris['Petal Length (cm)'], y = iris['Petal Width (cm)'], kind ='kde')
